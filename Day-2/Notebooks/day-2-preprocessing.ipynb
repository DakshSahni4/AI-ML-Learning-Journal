# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler

# %%
df = pd.read_csv("/kaggle/input/datasets/pradeepisawasan/dirty-iris-dataset/dirty_iris.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                NaN               0.2
# 2                4.7               3.2                NaN               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.isnull().any()
# Out:
# sepal length (cm)     True
# sepal width (cm)      True
# petal length (cm)     True
# petal width (cm)      True
# species              False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    23
# sepal width (cm)     15
# petal length (cm)    18
# petal width (cm)     16
# species               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
num_cols = df.select_dtypes(include = np.number).columns

# %%
num_cols
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5           1.400000               0.2
# 1                4.9               3.0           3.737879               0.2
# 2                4.7               3.2           3.737879               0.2
# 3                4.6               3.1           1.500000               0.2
# 4                5.0               3.6           1.400000               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
label_encoder = LabelEncoder()

df['species'] =  label_encoder.fit_transform(df["species"])

# %%
label_encoder.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5           1.400000               0.2
# 1                4.9               3.0           3.737879               0.2
# 2                4.7               3.2           3.737879               0.2
# 3                4.6               3.1           1.500000               0.2
# 4                5.0               3.6           1.400000               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
X = df.drop("species",axis = 1)
y = df["species"]

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2026)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %%
df.to_csv("cleaned_dirty_iris.csv",index=False)
